# %% [markdown]
# ## Homework 1.2 - Projectile motion under strong air resistance
#
# Consider a projectile problem under gravity $\mathbf g$ and air resistance that is directly proportional to the square of its speed, i.e. $c |\mathbf v|^2$.
#
# Given that $g = 9.8\;m/s^2$ and $c = 0.1\;m^{-1}$.
#
# Subjected to the initial conditions:
#
# $$x = 0, y = 0, v_x = 20 \; m/s \; \text{and}\;  v_y = 0$$
#
# First **write down** the governing equation of motion.
#
# Hence, **write down** the vector $\mathbf{v}$ and the matrix equation for $\frac{d\mathbf{v}}{dt}$.
#
# **Solve** the problem for $x$ and $y$ on the time interval $0 \le t \le 10\; s$..
#
# Then, **plot graph** of both components as function of time.

# %% [markdown]
# We have $\dot{x} = v_x$ and $\dot{v_x} = a_x$. Similarly, $\ddot{y} = \dot{v_y} = \dot{a_y}$.
#
# From Newton's law, we derive $$a_x = -c|\mathbf{v}|^2 \quad \text{and} \quad a_y = -(g+c|\mathbf{v}|^2)$$
#
# Hence, the vector *v* is $$\mathbf{v} = \begin{bmatrix} v_x \\ v_y\end{bmatrix}$$
#
# and its derivative with respect to time is $$ \frac{d}{dt}\mathbf{v} = \begin{bmatrix} -c|\mathbf{v}|^2 \\ -(g+c|\mathbf{v}|^2)\end{bmatrix}$$

# %%
import numpy as np
from scipy.integrate import odeint
from matplotlib import pyplot as plt

# %%
y0 = np.array([0,0,20,0])
def rhs(y,t):
    return np.array([y[2],y[3],-c*y[2]*(y[2]**2+y[3]**2)**(0.5),-g-c*y[3]*(y[2]**2+y[3]**2)**(0.5)])
c = 0.1
g= 9.8
t = np.arange(0,10,0.1)
ans = odeint(rhs,y0,t)
y = ans[:,1]
x = ans[:,0]

# %%
plt.plot(x,y)

# %%
plt.plot(t,x)

# %%
plt.plot(t,y)
